# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
supply_chain = pd.read_csv("E:\\Freelance-Projects\\project-3\\element_2_2nd_Copy\\DataCoSupplyChainDataset.csv",encoding='ISO-8859-1') 
supply_info = pd.read_csv("E:\\Freelance-Projects\\project-3\\element_2_2nd_Copy\\DescriptionDataCoSupplyChain.csv")

# %%
pd.set_option("display.max_columns", None)

# %%
supply_info
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
supply_chain.head(10)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
# 5  TRANSFER                         6                              4
# 6     DEBIT                         2                              1
# 7  TRANSFER                         2                              1
# 8      CASH                         3                              2
# 9      CASH                         2                              1
#
#    Benefit per order  Sales per customer    Delivery Status  \
# 0          91.250000          314.640015   Advance shipping
# 1        -249.089996          311.359985      Late delivery
# ...

# %%
supply_chain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
supply_chain.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
supply_chain[['Order Zipcode','Product Description']]
# Out:
#         Order Zipcode  Product Description
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
# ...               ...                  ...
# 180514            NaN                  NaN
# 180515            NaN                  NaN
# 180516            NaN                  NaN
# 180517            NaN                  NaN
# 180518            NaN                  NaN
#
# [180519 rows x 2 columns]

# %%
supply_chain.drop(['Order Zipcode','Product Description'],inplace = True, axis = 1)

# %%
supply_chain.dropna(inplace = True)

# %%
supply_chain.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   0
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
supply_chain.head(10)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
# 5  TRANSFER                         6                              4
# 6     DEBIT                         2                              1
# 7  TRANSFER                         2                              1
# 8      CASH                         3                              2
# 9      CASH                         2                              1
#
#    Benefit per order  Sales per customer    Delivery Status  \
# 0          91.250000          314.640015   Advance shipping
# 1        -249.089996          311.359985      Late delivery
# ...

# %%
supply_chain.drop(['Customer Email','Customer Password','Product Image'],inplace = True,axis = 1)

# %%
supply_chain.head(10)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
# 5  TRANSFER                         6                              4
# 6     DEBIT                         2                              1
# 7  TRANSFER                         2                              1
# 8      CASH                         3                              2
# 9      CASH                         2                              1
#
#    Benefit per order  Sales per customer    Delivery Status  \
# 0          91.250000          314.640015   Advance shipping
# 1        -249.089996          311.359985      Late delivery
# ...

# %%
#1st v
sns.countplot(x = 'Type',data = supply_chain,palette = 'magma',order = supply_chain['Type'].value_counts(ascending = True).index)
plt.title('Customer Transaction method')
plt.show()

# %%
#2nd v
plt.figure(figsize = (15,8))
sns.countplot(x = 'Category Name',data = supply_chain,palette = 'magma',order = supply_chain['Category Name'].value_counts(ascending = True).index)
plt.title('Product Category')
plt.xticks(rotation = 90)
plt.show()

# %%
#3rd v
plt.figure(figsize = (20,8))
sns.countplot(x = 'Product Name',data = supply_chain,palette = 'magma',order = supply_chain['Product Name'].value_counts(ascending = True).index)
plt.title('Product Name')
plt.xticks(rotation = 90)
plt.show()

# %%
#4th v
plt.figure(figsize = (17,8))
sns.countplot(x = 'Shipping Mode',data = supply_chain,palette = 'magma',order = supply_chain['Shipping Mode'].value_counts(ascending = True).index)
plt.title('Shipping mode')
plt.show()

# %%
#5th v
plt.figure(figsize = (17,8))
sns.countplot(x = 'Department Name',data = supply_chain,palette = 'magma',order = supply_chain['Department Name'].value_counts(ascending = True).index)
plt.title('Department Name')
plt.show()

# %%
#6th v
plt.figure(figsize = (17,8))
sns.countplot(x = 'Customer Segment',data = supply_chain,palette = 'magma',order = supply_chain['Customer Segment'].value_counts(ascending = True).index)
plt.title('Customer Category')
plt.show()

# %%
supply_chain['Order Country'].value_counts()
# Out:
# Estados Unidos       24840
# Francia              13221
# México               13172
# Alemania              9563
# Australia             8497
#                      ...
# Guinea Ecuatorial        2
# Kuwait                   2
# Sáhara Occidental        2
# Burundi                  1
# Serbia                   1
# Name: Order Country, Length: 164, dtype: int64

# %%
#7th v
plt.figure(figsize = (20,8))
sns.countplot(x = 'Order Country',data = supply_chain,palette = 'magma',order = supply_chain['Order Country'].value_counts(ascending = True).index)
plt.title('Order Country')
plt.xticks(rotation = 90)
plt.show()

# %%
#8th v
plt.figure(figsize = (15,8))
sns.countplot(x = 'Delivery Status',hue = 'Order Status',data = supply_chain,palette = 'magma',order = supply_chain['Delivery Status'].value_counts(ascending = True).index)
#plt.title('Order Country')
plt.show()

# %%
#9th v
# plt.figure(figsize = (15,8))
# sns.countplot(x = 'Delivery Status',hue = 'Order Status',data = supply_chain,palette = 'magma',order = supply_chain['Delivery Status'].value_counts(ascending = True).index)
# #plt.title('Order Country')
# plt.show()

# %%
supply_chain['Order Item Quantity'].value_counts()
# Out:
# 1    99123
# 5    20385
# 3    20350
# 4    20335
# 2    20315
# Name: Order Item Quantity, dtype: int64

# %%
supply_chain[supply_chain['Order Item Quantity'] == 5]['Product Name']
# Out:
# 92                 Nike Men's Dri-FIT Victory Golf Polo
# 93        Under Armour Girls' Toddler Spine Surge Runni
# 94        Under Armour Girls' Toddler Spine Surge Runni
# 95                 Nike Men's Dri-FIT Victory Golf Polo
# 96                 Nike Men's Dri-FIT Victory Golf Polo
#                               ...
# 179626                 Perfect Fitness Perfect Rip Deck
# 179627                 Perfect Fitness Perfect Rip Deck
# 179628                 Perfect Fitness Perfect Rip Deck
# 179629    Under Armour Girls' Toddler Spine Surge Runni
# 179630    adidas Youth Germany Black/Red Away Match Soc
# Name: Product Name, Length: 20385, dtype: object

# %%
supply_chain[['order date (DateOrders)','shipping date (DateOrders)']] = supply_chain[['order date (DateOrders)','shipping date (DateOrders)']].apply(pd.to_datetime)

# %%
supply_chain.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
supply_chain['Year'] = supply_chain['order date (DateOrders)'].dt.year
supply_chain['order_month'] = supply_chain['order date (DateOrders)'].dt.month
supply_chain['order_date'] = supply_chain['order date (DateOrders)'].dt.date

# %%
supply_chain.head(10)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
# 5  TRANSFER                         6                              4
# 6     DEBIT                         2                              1
# 7  TRANSFER                         2                              1
# 8      CASH                         3                              2
# 9      CASH                         2                              1
#
#    Benefit per order  Sales per customer    Delivery Status  \
# 0          91.250000          314.640015   Advance shipping
# 1        -249.089996          311.359985      Late delivery
# ...
